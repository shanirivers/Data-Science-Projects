# %% [markdown]
# # Share Price Data Cleaning
# The purpose of this notebook is to show how I cleaned and processed data.
#
# I will:
# 1. Import the data.
# 2. Once the data is imported, I will clean the data. This includes:
# 3. Handling missing values. I will check for null values using `.isnull()` and fill them in using `.fillna()` or remove the columns if they will not be needed for the analysis
# 4. Check for duplicates, `.duplicated()` and removing the duplicates, by using `.drop_duplicates()`
# 5. Converting data types by using `.astype()`

# %% [markdown]
# ## Import data

# %%
# libraries
import pandas as pd

# %%
# %%time
df = pd.read_csv('us-shareprices-daily.csv', delimiter=';')
len(df)
# Out:
# CPU times: user 2.01 s, sys: 660 ms, total: 2.67 s
# Wall time: 3.01 s
# 5322568

# %%
# Get a quick overview
df.head()
# Out:
#   Ticker  SimFinId        Date   Open   High    Low  Close  Adj. Close  \
# 0      A     45846  2018-08-07  66.83  67.94  66.63  67.66       64.78
# 1      A     45846  2018-08-08  67.74  68.15  67.34  67.38       64.51
# 2      A     45846  2018-08-09  67.48  67.62  66.61  66.69       63.85
# 3      A     45846  2018-08-10  66.82  66.87  65.93  66.26       63.44
# 4      A     45846  2018-08-13  66.44  66.99  65.67  65.94       63.13
#
#     Volume  Dividend  Shares Outstanding
# 0  2829039       NaN         319000000.0
# 1  1682000       NaN         319000000.0
# 2  1727776       NaN         319000000.0
# 3  2166251       NaN         319000000.0
# 4  2989306       NaN         319000000.0

# %%
# Get detailed information about the DataFrame df
df.info(verbose=True, memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5322568 entries, 0 to 5322567
# Data columns (total 11 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Ticker              object
#  1   SimFinId            int64
#  2   Date                object
#  3   Open                float64
#  4   High                float64
#  5   Low                 float64
#  6   Close               float64
#  7   Adj. Close          float64
#  8   Volume              int64
#  9   Dividend            float64
#  10  Shares Outstanding  float64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 1013.4 MB

# %% [markdown]
# It appears that the Dividend column only has 16 values.

# %%
df.describe()
# Out:
#            SimFinId          Open          High           Low         Close  \
# count  5.322568e+06  5.322568e+06  5.322568e+06  5.322568e+06  5.322568e+06
# mean   4.779305e+06  5.433237e+02  5.623159e+02  5.113188e+02  5.358395e+02
# std    5.219623e+06  4.523143e+04  4.701113e+04  4.163717e+04  4.443638e+04
# min    1.800000e+01  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    4.983910e+05  8.880000e+00  9.110000e+00  8.620000e+00  8.860000e+00
# 50%    1.108872e+06  2.210000e+01  2.255000e+01  2.164000e+01  2.208000e+01
# 75%    1.038350e+07  5.401000e+01  5.499000e+01  5.303000e+01  5.400000e+01
# max    1.566500e+07  1.200000e+07  1.200000e+07  1.200000e+07  1.200000e+07
#
#          Adj. Close        Volume      Dividend  Shares Outstanding
# count  5.322568e+06  5.322568e+06  34181.000000        4.942387e+06
# mean   5.238236e+02  1.830268e+06      0.400000        2.605399e+08
# std    4.441018e+04  3.020171e+07      0.902603        5.489286e+09
# min    0.000000e+00  0.000000e+00      0.000000        0.000000e+00
# 25%    8.320000e+00  4.278800e+04      0.120000        1.893059e+07
# 50%    2.053000e+01  2.607890e+05      0.240000        4.901730e+07
# 75%    5.090000e+01  9.622085e+05      0.450000        1.283296e+08
# max    1.200000e+07  1.848998e+10     68.060000        1.121052e+12

# %% [markdown]
# ## Handling missing values

# %%
print(df.isnull().sum())
# Out:
# Ticker                      0
# SimFinId                    0
# Date                        0
# Open                        0
# High                        0
# Low                         0
# Close                       0
# Adj. Close                  0
# Volume                      0
# Dividend              5288387
# Shares Outstanding     380181
# dtype: int64

# %% [markdown]
# The Dividend column contains a lot of null values. I do not need it for my analysis so I will define the columns I do want by adding them to a list that will use in the option, `usecols=required_cols`, to `read_csv` call for the final dataframe and when I create my final clean dataset.

# %%
# Define the required columns for the data
required_cols = ['Ticker', 'SimFinId', 'Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Shares Outstanding']

# %% [markdown]
# I will go ahead an drop the Dividend column and replace the null values on Shares Outstanding.

# %%
# Drop column 'Dividend'
df = df.drop('Dividend', axis=1)

# %%
df = df.fillna(0)

# %%
# Check info to see if it is dropped
df.info(verbose=True, memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5322568 entries, 0 to 5322567
# Data columns (total 10 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Ticker              object
#  1   SimFinId            int64
#  2   Date                object
#  3   Open                float64
#  4   High                float64
#  5   Low                 float64
#  6   Close               float64
#  7   Adj. Close          float64
#  8   Volume              int64
#  9   Shares Outstanding  float64
# dtypes: float64(6), int64(2), object(2)
# memory usage: 972.8 MB

# %%
print(df.isnull().sum())
# Out:
# Ticker                0
# SimFinId              0
# Date                  0
# Open                  0
# High                  0
# Low                   0
# Close                 0
# Adj. Close            0
# Volume                0
# Shares Outstanding    0
# dtype: int64

# %% [markdown]
# The Shares Outstanding column now as 0 as its value. I might remove this column if I find I do not need it for my analysis.

# %% [markdown]
# ## Check for duplicate values

# %%
# df.duplicated().sum()
df.groupby(df.columns.tolist(),as_index=False).size()
# Out:
#         Ticker  SimFinId        Date   Open   High    Low  Close  Adj. Close  \
# 0            A     45846  2018-08-07  66.83  67.94  66.63  67.66       64.78
# 1            A     45846  2018-08-08  67.74  68.15  67.34  67.38       64.51
# 2            A     45846  2018-08-09  67.48  67.62  66.61  66.69       63.85
# 3            A     45846  2018-08-10  66.82  66.87  65.93  66.26       63.44
# 4            A     45846  2018-08-13  66.44  66.99  65.67  65.94       63.13
# ...        ...       ...         ...    ...    ...    ...    ...         ...
# 5322563   ZYXI    171401  2023-07-05   9.50   9.54   9.15   9.17        9.17
# 5322564   ZYXI    171401  2023-07-06   9.02   9.18   8.93   9.01        9.01
# 5322565   ZYXI    171401  2023-07-07   9.03   9.29   8.94   9.00        9.00
# 5322566   ZYXI    171401  2023-07-10   9.00   9.23   8.99   9.18        9.18
# 5322567   ZYXI    171401  2023-07-11   9.08   9.34   8.98   9.06        9.06
#
#           Volume  Shares Outstanding  size
# 0        2829039         319000000.0     1
# 1        1682000         319000000.0     1
# 2        1727776         319000000.0     1
# 3        2166251         319000000.0     1
# 4        2989306         319000000.0     1
# ...          ...                 ...   ...
# 5322563   215455          36435000.0     1
# 5322564   191404          36435000.0     1
# 5322565   291326          36435000.0     1
# 5322566   148425          36435000.0     1
# 5322567   173802          36435000.0     1
#
# [5322568 rows x 11 columns]

# %% [markdown]
# Determine if there are duplicates.

# %%
duplicates = df[df.duplicated()] 
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Ticker, SimFinId, Date, Open, High, Low, Close, Adj. Close, Volume, Shares Outstanding]
# Index: []

# %% [markdown]
# There are no duplicates in the dataset.

# %% [markdown]
# ## Converting data types
# Define what data types will be best so that they don't use too much memory.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5322568 entries, 0 to 5322567
# Data columns (total 10 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Ticker              object
#  1   SimFinId            int64
#  2   Date                object
#  3   Open                float64
#  4   High                float64
#  5   Low                 float64
#  6   Close               float64
#  7   Adj. Close          float64
#  8   Volume              int64
#  9   Shares Outstanding  float64
# dtypes: float64(6), int64(2), object(2)
# memory usage: 406.1+ MB

# %% [markdown]
# I tried to change the float64 and int64 down to float16 and int16, but this was too low and adversely affected the data so I reloaded the dataset again and found that float32 and int32, worked best.
#
# I will change the float and int datatypes to float32 and int32, respectively, and the tickers to category. I changed the Date column manually, but when I bring in the dataset again, I will use `parse_date()` option on the `read_csv` call.

# %%
for col in df.columns:
    if df[col].dtype == 'float64':
        df[col] = df[col].astype('float32')
    if df[col].dtype == 'int64':
        df[col] = df[col].astype('int32')
    if df[col].dtype == 'object' and df[col].name == 'Ticker':
        df[col] = df[col].astype('category')
    if df[col].name == 'Date':
        df[col] = df[col].astype('datetime64[ns]')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5322568 entries, 0 to 5322567
# Data columns (total 10 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Ticker              category
#  1   SimFinId            int32
#  2   Date                datetime64[ns]
#  3   Open                float32
#  4   High                float32
#  5   Low                 float32
#  6   Close               float32
#  7   Adj. Close          float32
#  8   Volume              int32
#  9   Shares Outstanding  float32
# dtypes: category(1), datetime64[ns](1), float32(6), int32(2)
# memory usage: 213.4 MB

# %% [markdown]
# The code above loops through the columns and changes the type. The memory usage dropped by almost half.
#
# Run `.head()` and `.describe` again to see if changing the types did anything adversely to the data.

# %%
df.head()
# Out:
#   Ticker  SimFinId       Date       Open       High        Low      Close  \
# 0      A     45846 2018-08-07  66.830002  67.940002  66.629997  67.660004
# 1      A     45846 2018-08-08  67.739998  68.150002  67.339996  67.379997
# 2      A     45846 2018-08-09  67.480003  67.620003  66.610001  66.690002
# 3      A     45846 2018-08-10  66.820000  66.870003  65.930000  66.260002
# 4      A     45846 2018-08-13  66.440002  66.989998  65.669998  65.940002
#
#    Adj. Close   Volume  Shares Outstanding
# 0   64.779999  2829039         319000000.0
# 1   64.510002  1682000         319000000.0
# 2   63.849998  1727776         319000000.0
# 3   63.439999  2166251         319000000.0
# 4   63.130001  2989306         319000000.0

# %%
df.describe()
# Out:
#            SimFinId                           Date          Open  \
# count  5.322568e+06                        5322568  5.322568e+06
# mean   4.779305e+06  2021-02-25 05:37:53.133722112  5.433233e+02
# min    1.800000e+01            2018-08-07 00:00:00  0.000000e+00
# 25%    4.983910e+05            2019-12-10 00:00:00  8.880000e+00
# 50%    1.108872e+06            2021-03-23 00:00:00  2.210000e+01
# 75%    1.038350e+07            2022-05-17 00:00:00  5.401000e+01
# max    1.566500e+07            2023-07-11 00:00:00  1.200000e+07
# std    5.219623e+06                            NaN  4.522812e+04
#
#                High           Low         Close    Adj. Close        Volume  \
# count  5.322568e+06  5.322568e+06  5.322568e+06  5.322568e+06  5.322568e+06
# mean   5.623159e+02  5.113192e+02  5.358393e+02  5.238233e+02  1.694702e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00 -2.125784e+09
# 25%    9.110000e+00  8.620000e+00  8.860000e+00  8.320000e+00  4.277800e+04
# 50%    2.255000e+01  2.164000e+01  2.208000e+01  2.053000e+01  2.607500e+05
# 75%    5.499000e+01  5.303000e+01  5.400000e+01  5.090000e+01  9.620678e+05
# max    1.200000e+07  1.200000e+07  1.200000e+07  1.200000e+07  2.146534e+09
# std    4.700781e+04  4.163399e+04  4.443310e+04  4.440703e+04  1.609591e+07
#
#        Shares Outstanding
# count        5.322568e+06
# mean         2.419301e+08
# min          0.000000e+00
# 25%          1.370800e+07
# 50%          4.322318e+07
# 75%          1.177667e+08
# max          1.121052e+12
# std          5.285733e+09

# %% [markdown]
# A dictionary variable will be used in the `read_csv()` call to change datatype when I bring in the clean dataset and I will add an option on the `read_csv` function to change the Date column to the correct datetype when I bring in the data.

# %% [markdown]
# ## Check data by running queries

# %%
# Pull data by Ticker
gme_stock_data = df[df['Ticker'] == 'GME']
gme_stock_data
# Out:
#         Ticker  SimFinId       Date       Open       High        Low  \
# 2053021    GME     44534 2018-08-07   3.730000   3.810000   3.710000
# 2053022    GME     44534 2018-08-08   3.780000   3.830000   3.750000
# 2053023    GME     44534 2018-08-09   3.810000   3.870000   3.750000
# 2053024    GME     44534 2018-08-10   3.790000   3.900000   3.770000
# 2053025    GME     44534 2018-08-13   3.840000   3.850000   3.780000
# ...        ...       ...        ...        ...        ...        ...
# 2054255    GME     44534 2023-07-05  24.639999  24.850000  23.790001
# 2054256    GME     44534 2023-07-06  23.520000  23.570000  22.820000
# 2054257    GME     44534 2023-07-07  22.969999  23.530001  22.670000
# 2054258    GME     44534 2023-07-10  22.610001  23.559999  22.000000
# 2054259    GME     44534 2023-07-11  23.200001  24.440001  23.200001
#
#              Close  Adj. Close   Volume  Shares Outstanding
# 2053021   3.780000    3.470000  7813724         407600000.0
# 2053022   3.810000    3.500000  8715468         407600000.0
# 2053023   3.800000    3.490000  9370924         407600000.0
# 2053024   3.830000    3.520000  9666664         407600000.0
# 2053025   3.800000    3.490000  8403788         407600000.0
# ...            ...         ...      ...                 ...
# 2054255  23.900000   23.900000  2268244         304500000.0
# 2054256  22.830000   22.830000  2390303         304500000.0
# 2054257  22.709999   22.709999  2447203         304500000.0
# 2054258  23.540001   23.540001  3318214         304500000.0
# 2054259  23.910000   23.910000  3063534         304500000.0
#
# [1239 rows x 10 columns]

# %%
# see if the data type change on date was successful

df['Date'] = pd.to_datetime(df['Date'])

# Set a new dataframe with the filtered data for year 2022, reset index
stock_data_2022 = df[df['Date'].dt.year == 2022].reset_index()

stock_data_2022
# Out:
#            index Ticker  SimFinId       Date        Open        High  \
# 0            858      A     45846 2022-01-03  159.000000  159.440002
# 1            859      A     45846 2022-01-04  155.490005  155.630005
# 2            860      A     45846 2022-01-05  150.830002  153.100006
# 3            861      A     45846 2022-01-06  148.850006  149.960007
# 4            862      A     45846 2022-01-07  149.119995  149.729996
# ...          ...    ...       ...        ...         ...         ...
# 1171069  5322433   ZYXI    171401 2022-12-23   13.630000   14.070000
# 1171070  5322434   ZYXI    171401 2022-12-27   14.020000   14.090000
# 1171071  5322435   ZYXI    171401 2022-12-28   13.690000   13.900000
# 1171072  5322436   ZYXI    171401 2022-12-29   13.950000   14.200000
# 1171073  5322437   ZYXI    171401 2022-12-30   13.800000   13.980000
#
#                 Low       Close  Adj. Close   Volume  Shares Outstanding
# 0        153.929993  156.479996  153.809998  1606323         302722656.0
# 1        149.699997  151.190002  148.610001  2233958         302722656.0
# 2        148.529999  148.600006  146.070007  2370529         302722656.0
# 3        145.580002  149.119995  146.580002  2298277         302722656.0
# 4        145.089996  145.149994  142.679993  2058658         302722656.0
# ...             ...         ...         ...      ...                 ...
# 1171069   13.630000   13.810000   13.810000   180392          38046000.0
# 1171070   13.670000   13.760000   13.760000   143701          38046000.0
# 1171071   13.630000   13.880000   13.880000   137809          38046000.0
# 1171072   13.810000   13.870000   13.870000   159746          38046000.0
# 1171073   13.710000   13.910000   13.910000   235576          38046000.0
#
# [1171074 rows x 11 columns]

# %% [markdown]
# Determine if my new dataframe has only 2022 dates.

# %%
stock_data_2022['Date'].agg(['min', 'max'])
# Out:
# min   2022-01-03
# max   2022-12-30
# Name: Date, dtype: datetime64[ns]

# %% [markdown]
# I have successfully brought in data from only 2022.

# %%
stock_data_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1171074 entries, 0 to 1171073
# Data columns (total 11 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   index               1171074 non-null  int64
#  1   Ticker              1171074 non-null  category
#  2   SimFinId            1171074 non-null  int32
#  3   Date                1171074 non-null  datetime64[ns]
#  4   Open                1171074 non-null  float32
#  5   High                1171074 non-null  float32
#  6   Low                 1171074 non-null  float32
#  7   Close               1171074 non-null  float32
#  8   Adj. Close          1171074 non-null  float32
#  9   Volume              1171074 non-null  int32
#  10  Shares Outstanding  1171074 non-null  float32
# dtypes: category(1), datetime64[ns](1), float32(6), int32(2), int64(1)
# memory usage: 56.0 MB

# %% [markdown]
# Look at the first 10 records.

# %%
stock_data_2022.head(10)
# Out:
#    index Ticker  SimFinId       Date        Open        High         Low  \
# 0    858      A     45846 2022-01-03  159.000000  159.440002  153.929993
# 1    859      A     45846 2022-01-04  155.490005  155.630005  149.699997
# 2    860      A     45846 2022-01-05  150.830002  153.100006  148.529999
# 3    861      A     45846 2022-01-06  148.850006  149.960007  145.580002
# 4    862      A     45846 2022-01-07  149.119995  149.729996  145.089996
# 5    863      A     45846 2022-01-10  143.289993  145.309998  140.860001
# 6    864      A     45846 2022-01-11  145.000000  146.940002  143.809998
# 7    865      A     45846 2022-01-12  147.800003  150.389999  147.550003
# 8    866      A     45846 2022-01-13  149.460007  149.539993  144.850006
# 9    867      A     45846 2022-01-14  144.039993  145.149994  142.360001
#
#         Close  Adj. Close   Volume  Shares Outstanding
# 0  156.479996  153.809998  1606323         302722656.0
# 1  151.190002  148.610001  2233958         302722656.0
# 2  148.600006  146.070007  2370529         302722656.0
# 3  149.119995  146.580002  2298277         302722656.0
# 4  145.149994  142.679993  2058658         302722656.0
# 5  145.160004  142.690002  2548145         302722656.0
# 6  146.639999  144.139999  2028671         302722656.0
# 7  149.509995  146.960007  2250847         302722656.0
# 8  145.169998  142.690002  1741764         302722656.0
# 9  144.679993  142.210007  2225442         302722656.0

# %% [markdown]
# Change the Date column back to an Object type, as it uses less memory.

# %%
from datetime import datetime
def convert_datetime(dt):
    return datetime.strftime(dt, '%Y-%m-%d') # Change it back to the original format it came in

stock_data_2022['Date']= stock_data_2022['Date'].apply(convert_datetime)

# %%
stock_data_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1171074 entries, 0 to 1171073
# Data columns (total 11 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   index               1171074 non-null  int64
#  1   Ticker              1171074 non-null  category
#  2   SimFinId            1171074 non-null  int32
#  3   Date                1171074 non-null  object
#  4   Open                1171074 non-null  float32
#  5   High                1171074 non-null  float32
#  6   Low                 1171074 non-null  float32
#  7   Close               1171074 non-null  float32
#  8   Adj. Close          1171074 non-null  float32
#  9   Volume              1171074 non-null  int32
#  10  Shares Outstanding  1171074 non-null  float32
# dtypes: category(1), float32(6), int32(2), int64(1), object(1)
# memory usage: 56.0+ MB

# %% [markdown]
# ## Create new CSV file from filtered dataframe
#
# Push the new dataframe that is filtered for 2022 into a new CSV file.

# %%
# Push the new dataframe and convert it to a CSV
stock_data_2022.to_csv('US_Share_Prices_2022.csv', index=False)

# %% [markdown]
# Import and inspect new file to make sure that it contains the data that I need.

# %%
# Define the required columns for the data
required_cols = ['Ticker', 'SimFinId', 'Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Shares Outstanding']

# %% [markdown]
# # Define the data types dictionary for the columns
# dt_setup = {
#     'Ticker':'category',
#     'Open':'float32',
#     'High':'float32',
#     'Low':'float32',
#     'Close':'float32'
# }

# %%
# %%time
new_df = pd.read_csv('US_Share_Prices_2022.csv', delimiter=',', usecols=required_cols, dtype=dt_setup, parse_dates=[2])
len(df)
# Out:
# CPU times: user 470 ms, sys: 69.4 ms, total: 540 ms
# Wall time: 568 ms
# 5322568

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1171074 entries, 0 to 1171073
# Data columns (total 9 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   Ticker              1171074 non-null  category
#  1   SimFinId            1171074 non-null  int64
#  2   Date                1171074 non-null  datetime64[ns]
#  3   Open                1171074 non-null  float32
#  4   High                1171074 non-null  float32
#  5   Low                 1171074 non-null  float32
#  6   Close               1171074 non-null  float32
#  7   Volume              1171074 non-null  int64
#  8   Shares Outstanding  1171074 non-null  float64
# dtypes: category(1), datetime64[ns](1), float32(4), float64(1), int64(2)
# memory usage: 56.0 MB

# %% [markdown]
# The new dataframe with the filtered data has been pulled in correctly.

# %%
new_df.head(10)
# Out:
#   Ticker  SimFinId       Date        Open        High         Low       Close  \
# 0      A     45846 2022-01-03  159.000000  159.440002  153.929993  156.479996
# 1      A     45846 2022-01-04  155.490005  155.630005  149.699997  151.190002
# 2      A     45846 2022-01-05  150.830002  153.100006  148.529999  148.600006
# 3      A     45846 2022-01-06  148.850006  149.960007  145.580002  149.119995
# 4      A     45846 2022-01-07  149.119995  149.729996  145.089996  145.149994
# 5      A     45846 2022-01-10  143.289993  145.309998  140.860001  145.160004
# 6      A     45846 2022-01-11  145.000000  146.940002  143.809998  146.639999
# 7      A     45846 2022-01-12  147.800003  150.389999  147.550003  149.509995
# 8      A     45846 2022-01-13  149.460007  149.539993  144.850006  145.169998
# 9      A     45846 2022-01-14  144.039993  145.149994  142.360001  144.679993
#
#     Volume  Shares Outstanding
# 0  1606323         302722660.0
# 1  2233958         302722660.0
# 2  2370529         302722660.0
# 3  2298277         302722660.0
# 4  2058658         302722660.0
# 5  2548145         302722660.0
# 6  2028671         302722660.0
# 7  2250847         302722660.0
# 8  1741764         302722660.0
# 9  2225442         302722660.0

# %%
new_df.describe()
# Out:
#            SimFinId                           Date          Open  \
# count  1.171074e+06                        1171074  1.171074e+06
# mean   5.383653e+06  2022-07-02 07:52:53.044231168  1.785455e+02
# min    1.800000e+01            2022-01-03 00:00:00  0.000000e+00
# 25%    6.277770e+05            2022-04-01 00:00:00  7.440000e+00
# 50%    1.299451e+06            2022-07-05 00:00:00  1.919000e+01
# 75%    1.103405e+07            2022-09-30 00:00:00  4.905000e+01
# max    1.566500e+07            2022-12-30 00:00:00  5.443892e+05
# std    5.430753e+06                            NaN  6.925252e+03
#
#                High           Low         Close        Volume  \
# count  1.171074e+06  1.171074e+06  1.171074e+06  1.171074e+06
# mean   1.817529e+02  1.745826e+02  1.777829e+02  1.667077e+06
# min    0.000000e+00  0.000000e+00  0.000000e+00 -2.125784e+09
# 25%    7.670000e+00  7.200000e+00  7.420000e+00  3.899700e+04
# 50%    1.962000e+01  1.876000e+01  1.917000e+01  2.599760e+05
# 75%    5.000000e+01  4.808000e+01  4.904000e+01  9.570310e+05
# max    5.443892e+05  5.333451e+05  5.391800e+05  2.094306e+09
# std    6.994762e+03  6.820709e+03  6.903116e+03  1.248339e+07
#
#        Shares Outstanding
# count        1.171074e+06
# mean         3.019733e+08
# min          0.000000e+00
# 25%          1.632500e+07
# 50%          4.718758e+07
# 75%          1.271952e+08
# max          3.397416e+11
# std          5.239273e+09

# %% [markdown]
# Check the dates:

# %%
stock_data_2022['Date'].agg(['min', 'max'])
# Out:
# min    2022-01-03
# max    2022-12-30
# Name: Date, dtype: object

# %% [markdown]
# ## Future Code for bringing in a updated CSV from SimFin
# From the analysis of the existing data, I will use defined required columns and data types to create a new file to work from that will also pull only the filtered data for 2022.

# %%
# Define the required columns for the data
required_cols = ['Ticker', 'SimFinId', 'Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Shares Outstanding']

# %%
# Define the data types for the columns
dt_setup = {
    'Ticker':'category',
    'Open':'float32',
    'High':'float32',
    'Low':'float32',
    'Close':'float32'
}

# %%
# %%time
# Use nrows option
df = pd.read_csv('us-shareprices-daily.csv', delimiter=';', nrows=1000, usecols=required_cols, dtype=dt_setup, date_parse(2))
len(df)
# Out:
# CPU times: user 10.8 ms, sys: 5.05 ms, total: 15.9 ms
# Wall time: 18.7 ms
# 1000

# %%
# Fill na to zero the column, Shares Outstanding 
df = df.fillna(0)

# %% [markdown]
# Code for converting dataframe to JSON and compressed JSON:

# %%
# df.to_json('US_Share_Prices_2022.json', orient='records', lines=True)

# %%
# df.to_json('US_Share_Prices_2022.json.gz', orient='records', lines=True, compression='gzip')

# %%
# List out dates
df['Date'].dt.date
# Out:
# 0      2018-08-07
# 1      2018-08-08
# 2      2018-08-09
# 3      2018-08-10
# 4      2018-08-13
#           ...
# 995    2022-07-21
# 996    2022-07-22
# 997    2022-07-25
# 998    2022-07-26
# 999    2022-07-27
# Name: Date, Length: 1000, dtype: object

# %%
data_for_desired_year = df[df['Date'].dt.year == 2022]

# %%
print(data_for_desired_year)
# Out:
#     Ticker  SimFinId       Date        Open        High         Low  \
# 858      A    -19690 2022-01-03  159.000000  159.440002  153.929993
# 859      A    -19690 2022-01-04  155.490005  155.630005  149.699997
# 860      A    -19690 2022-01-05  150.830002  153.100006  148.529999
# 861      A    -19690 2022-01-06  148.850006  149.960007  145.580002
# 862      A    -19690 2022-01-07  149.119995  149.729996  145.089996
# ..     ...       ...        ...         ...         ...         ...
# 995      A    -19690 2022-07-21  122.120003  127.339996  122.120003
# 996      A    -19690 2022-07-22  127.410004  128.539993  124.309998
# 997      A    -19690 2022-07-25  125.050003  125.410004  123.190002
# 998      A    -19690 2022-07-26  124.660004  125.629997  123.370003
# 999      A    -19690 2022-07-27  125.040001  128.330002  124.709999
#
#           Close  Volume
# 858  156.479996  -32077
# 859  151.190002    5734
# 860  148.600006   11233
# 861  149.119995    4517
# 862  145.149994   27042
# ..          ...     ...
# 995  127.190002  -21377
# 996  125.040001   30890
# 997  124.260002   -4569
# 998  125.169998   14773
# 999  127.709999   19689
#
# [142 rows x 8 columns]
